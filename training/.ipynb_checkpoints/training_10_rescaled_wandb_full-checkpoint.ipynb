# %% [markdown]
# in this notebook we:
# * stage 6 - rescaled images, no further downsizing

# %%
from pathlib import Path
import json
import logging

import numpy as np
import pandas as pd

from fastai.vision import *

import os

import wandb
from wandb.fastai import WandbCallback

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

import configparser

from functions_wandb import *

# %%
# %matplotlib inline

# %%
wandb.init(project="gabon")
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/jedrzej/gabon" target="_blank">https://app.wandb.ai/jedrzej/gabon</a><br/>
#                 Run page: <a href="https://app.wandb.ai/jedrzej/gabon/runs/16u8ljoz" target="_blank">https://app.wandb.ai/jedrzej/gabon/runs/16u8ljoz</a><br/>
# W&B Run: https://app.wandb.ai/jedrzej/gabon/runs/16u8ljoz

# %%
# PATH_TO_IMG = Path("/data_rescaled")

# PATH_TO_MAIN = Path("/home/jupyter/")
# PATH_TO_TRAIN_DF = PATH_TO_MAIN / "inspect_data_split_validation"
# PATH_TO_MODELS = PATH_TO_MAIN / "training" / "saved_models"
# PATH_TO_CONFIG = PATH_TO_MAIN / "config"

# CONFIG = configparser.ConfigParser()
# CONFIG.read(PATH_TO_CONFIG / "neptune.ini")

# %%
df = pd.read_csv(PATH_TO_TRAIN_DF / "train_valid_df.csv")

classes = df.species.unique()
print(len(classes)) # no "Mammal_Other"
classes
# Out:
# 28
# array(['Human', 'Blank', 'Elephant_African', 'Hog_Red_River', 'Buffalo_African', 'Leopard_African', 'Monkey',
#        'Duiker_Red', 'Civet_African_Palm', 'Squirrel', 'Duiker_Blue', 'Bird', 'Mongoose_Black_Footed', 'Rodent',
#        'Duiker_Yellow_Backed', 'Genet', 'Chimpanzee', 'Gorilla', 'Mongoose', 'Porcupine_Brush_Tailed', 'Pangolin',
#        'Mandrillus', 'Chevrotain_Water', 'Cat_Golden', 'Rat_Giant', 'Guineafowl_Crested', 'Guineafowl_Black',
#        'Rail_Nkulengu'], dtype=object)

# %%
len(df.uniqueName)
# Out:
# 347120

# %%
df.head()
# Out:
#     uniqueName species                    main_folder  is_valid sub_folder
# 0  0000005.jpg   Human  Compressed Camera Trap Images     False        T33
# 1  0000007.jpg   Human  Compressed Camera Trap Images     False        T33
# 2  0000009.jpg   Human  Compressed Camera Trap Images     False        T33
# 3  0000013.jpg   Human  Compressed Camera Trap Images     False        T33
# 4  0000015.jpg   Human  Compressed Camera Trap Images     False        T33

# %%
df["uniqueName"] = df.uniqueName.apply(lambda x: "resc_" + x)
df.head()
# Out:
#          uniqueName species                    main_folder  is_valid  \
# 0  resc_0000005.jpg   Human  Compressed Camera Trap Images     False
# 1  resc_0000007.jpg   Human  Compressed Camera Trap Images     False
# 2  resc_0000009.jpg   Human  Compressed Camera Trap Images     False
# 3  resc_0000013.jpg   Human  Compressed Camera Trap Images     False
# 4  resc_0000015.jpg   Human  Compressed Camera Trap Images     False
#
#   sub_folder
# 0        T33
# 1        T33
# 2        T33
# 3        T33
# 4        T33

# %%
# %%time
data = get_training_data(df, (384, 512), batch_size=32)#, partial_pct=0.01)
# Out:
# CPU times: user 4.14 s, sys: 200 ms, total: 4.34 s
# Wall time: 3.62 s

# %%
# %%time
data.show_batch()
# Out:
# CPU times: user 4.91 s, sys: 1.23 s, total: 6.14 s
# Wall time: 4.75 s

# %% [markdown]
# # Stage 6

# %%
learn = get_initial_learner(data)
learn.load(PATH_TO_MODELS / "stage5-2epochs-384_512-rescaled");

# %%
learn.unfreeze()

# %%
# %%time
run_find_lr(learn, "stage6-5epochs-384_512-rescaled")
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# /opt/anaconda3/lib/python3.7/site-packages/plotly/matplotlylib/mpltools.py:368: MatplotlibDeprecationWarning:
#
#
# The is_frame_like function was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# CPU times: user 14.7 s, sys: 6.27 s, total: 21 s
# Wall time: 35.2 s

# %%
learn.recorder.plot()

# %%
initial_lr = 1e-4 * 5
lr = 1e-5 / 2
lr_end = initial_lr / 10
n_epochs =  5

# %%
# %%time
run_training(learn, "stage6-5epochs-384_512-rescaled", lr=lr, lr_end=lr_end, n_epochs=n_epochs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.423953</td>
#       <td>1.147621</td>
#       <td>0.698382</td>
#       <td>1:10:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.310257</td>
#       <td>0.979974</td>
#       <td>0.733107</td>
#       <td>1:10:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.229255</td>
#       <td>1.107114</td>
#       <td>0.728408</td>
#       <td>1:10:48</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.173666</td>
#       <td>0.993905</td>
#       <td>0.743422</td>
#       <td>1:11:52</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.156040</td>
#       <td>0.977391</td>
#       <td>0.751398</td>
#       <td>1:10:51</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.1476212739944458.
# Better model found at epoch 1 with valid_loss value: 0.9799739718437195.
# Better model found at epoch 4 with valid_loss value: 0.9773914217948914.
# Loaded best saved model from /home/jupyter/training/wandb/run-20200312_202500-29usd74j/bestmodel.pth
# CPU times: user 2h 50min 44s, sys: 58min 44s, total: 3h 49min 28s
# Wall time: 5h 54min 24s

# %%
learn.recorder.plot_losses()

# %%
fig = learn.recorder.plot_losses(return_fig=True)
fig.savefig("loss_plot-stage6-5epochs-384_512-rescaled.png")

# %% [markdown]
# ### Load model and investigate results

# %%
learn = get_initial_learner(data)
learn.load(PATH_TO_MODELS / "stage6-5epochs-384_512-rescaled");

# %%
# wandb.init(project="gabon")
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/jedrzej/gabon" target="_blank">https://app.wandb.ai/jedrzej/gabon</a><br/>
#                 Run page: <a href="https://app.wandb.ai/jedrzej/gabon/runs/39mr90sv" target="_blank">https://app.wandb.ai/jedrzej/gabon/runs/39mr90sv</a><br/>
# W&B Run: https://app.wandb.ai/jedrzej/gabon/runs/39mr90sv

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
conf_m = interp.confusion_matrix()
np.save("conf_m-stage6-5epochs-384_512-rescaled.npy", conf_m)

# %%
len(conf_m)
# Out:
# 28

# %%
correct_p = sum([conf_m[i,i] for i in range(len(conf_m))])
correct_p
# Out:
# 32782

# %%
all_p = conf_m.sum().sum()
all_p
# Out:
# 43628

# %%
print(f"accuracy is: {round(100 * correct_p / all_p,2)}%")
# Out:
# accuracy is: 75.14%

# %%
new_order = np.load("new_order.npy")
plot_conf_matrix_reordered(conf_m, 
                           sorted(classes),
                           new_order,
                           save_as = "conf_m-new_order-stage6-5epochs-384_512-rescaled.png",
                           for_model = "stage6-5epochs-384_512-rescaled")
