# %% [markdown]
# in this notebook we:
# * stage 3 - rescaled images, but then downscaled only by 2

# %%
from pathlib import Path
import json
import logging

import numpy as np
import pandas as pd

from fastai.vision import *

import os

import wandb
from wandb.fastai import WandbCallback

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

import configparser

from functions_wandb import *

# %%
# %matplotlib inline

# %%
wandb.init(project="gabon")
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/jedrzej/gabon" target="_blank">https://app.wandb.ai/jedrzej/gabon</a><br/>
#                 Run page: <a href="https://app.wandb.ai/jedrzej/gabon/runs/2i5lrz8e" target="_blank">https://app.wandb.ai/jedrzej/gabon/runs/2i5lrz8e</a><br/>
# W&B Run: https://app.wandb.ai/jedrzej/gabon/runs/2i5lrz8e

# %%
# ! pip install wandb

# %%
# logging.basicConfig(level=logging.INFO)

# %%
# PATH_TO_IMG = Path("/data_rescaled")

# PATH_TO_MAIN = Path("/home/jupyter/")
# PATH_TO_TRAIN_DF = PATH_TO_MAIN / "inspect_data_split_validation"
# PATH_TO_MODELS = PATH_TO_MAIN / "training" / "saved_models"
# PATH_TO_CONFIG = PATH_TO_MAIN / "config"

# CONFIG = configparser.ConfigParser()
# CONFIG.read(PATH_TO_CONFIG / "neptune.ini")

# %%
# ! pip install neptune-client neptune-contrib

# %%
# neptune.init(project_qualified_name='appsilon/gabon-wildlife', 
#             api_token=CONFIG["neptune"]["NEPTUNE_API_TOKEN"])

# %%
df = pd.read_csv(PATH_TO_TRAIN_DF / "train_valid_df.csv")

classes = df.species.unique()
print(len(classes)) # no "Mammal_Other"
classes
# Out:
# 28
# array(['Human', 'Blank', 'Elephant_African', 'Hog_Red_River', 'Buffalo_African', 'Leopard_African', 'Monkey',
#        'Duiker_Red', 'Civet_African_Palm', 'Squirrel', 'Duiker_Blue', 'Bird', 'Mongoose_Black_Footed', 'Rodent',
#        'Duiker_Yellow_Backed', 'Genet', 'Chimpanzee', 'Gorilla', 'Mongoose', 'Porcupine_Brush_Tailed', 'Pangolin',
#        'Mandrillus', 'Chevrotain_Water', 'Cat_Golden', 'Rat_Giant', 'Guineafowl_Crested', 'Guineafowl_Black',
#        'Rail_Nkulengu'], dtype=object)

# %%
len(df.uniqueName)
# Out:
# 347120

# %%
df.head()
# Out:
#     uniqueName species                    main_folder  is_valid sub_folder
# 0  0000005.jpg   Human  Compressed Camera Trap Images     False        T33
# 1  0000007.jpg   Human  Compressed Camera Trap Images     False        T33
# 2  0000009.jpg   Human  Compressed Camera Trap Images     False        T33
# 3  0000013.jpg   Human  Compressed Camera Trap Images     False        T33
# 4  0000015.jpg   Human  Compressed Camera Trap Images     False        T33

# %%
df["uniqueName"] = df.uniqueName.apply(lambda x: "resc_" + x)
df.head()
# Out:
#          uniqueName species                    main_folder  is_valid  \
# 0  resc_0000005.jpg   Human  Compressed Camera Trap Images     False
# 1  resc_0000007.jpg   Human  Compressed Camera Trap Images     False
# 2  resc_0000009.jpg   Human  Compressed Camera Trap Images     False
# 3  resc_0000013.jpg   Human  Compressed Camera Trap Images     False
# 4  resc_0000015.jpg   Human  Compressed Camera Trap Images     False
#
#   sub_folder
# 0        T33
# 1        T33
# 2        T33
# 3        T33
# 4        T33

# %%
# %%time
data = get_training_data(df, (384 // 2, 512 // 2), batch_size=128)#, partial_pct=0.01)
# Out:
# CPU times: user 7.95 s, sys: 356 ms, total: 8.3 s
# Wall time: 6.22 s

# %%
# %%time
# data.show_batch()
# Out:
# CPU times: user 28.8 s, sys: 1.33 s, total: 30.1 s
# Wall time: 23.4 s

# %% [markdown]
# # Stage 3

# %%
learn = get_initial_learner(data)
learn.load(PATH_TO_MODELS / "stage2-6epochs-96_128-rescaled");

# %%
learn.freeze()

# %%
# %%time
run_find_lr(learn, "stage3-1epochs-192_256-rescaled")
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# CPU times: user 18.9 s, sys: 7.08 s, total: 26 s
# Wall time: 2min 1s

# %%
learn.recorder.plot()

# %%
initial_lr = 1e-4 * 2

# %%
# %%time
run_training(learn, "stage3-1epochs-192_256-rescaled", lr=initial_lr, n_epochs=1) 
# used to be called stage3-1epochs-96_128-rescaled, changed later in names of saved files
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='2371', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Loaded best saved model from /home/jupyter/training/wandb/run-20200312_111837-2i5lrz8e/bestmodel.pth
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# ~/training/functions_wandb.py in run_training(learn, model_name, lr, n_epochs, lr_end)
#      86             lr_slice = slice(lr, lr_end)
#      87
# ---> 88         learn.fit_one_cycle(n_epochs, lr_slice)
#      89         logging.info(f"finished training {model_name}")
#      90         save_model(learn, model_name)
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      21     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      22                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 23     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      24
#      25 def fit_fc(learn:Learner, tot_epochs:int=1, lr:float=defaults.lr,  moms:Tuple[float,float]=(0.95,0.85), start_pct:float=0.72,
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      33         loss,skip_bwd = cb_handler.on_backward_begin(loss)
#      34         if not skip_bwd:                     loss.backward()
# ---> 35         if not cb_handler.on_backward_end(): opt.step()
#      36         if not cb_handler.on_step_end():     opt.zero_grad()
#      37
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/callback.py in step(self)
#      55                     for p in pg2['params']: p.data.mul_(1 - wd*lr)
#      56             self.set_val('weight_decay', listify(0, self._wd))
# ---> 57         self.opt.step()
#      58
#      59     def zero_grad(self)->None:
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/optim/adam.py in step(self, closure)
#     101                     denom = (max_exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(group['eps'])
#     102                 else:
# --> 103                     denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(group['eps'])
#     104
#     105                 step_size = group['lr'] / bias_correction1
#
# KeyboardInterrupt:

# %%
learn.recorder.plot_losses()

# %%
fig = learn.recorder.plot_losses()
fig.savefig("stage3-1epochs-192_256-rescaled")

# %%
# learn = load_learner(PATH_TO_MODELS, "stage1-1epochs-96_128-rescaled.pkl")
# learn.data = data
learn = get_initial_learner(data)
learn.load(PATH_TO_MODELS / "stage1-1epochs-96_128-rescaled");

# %% [markdown]
# # Stage 2

# %%
learn.unfreeze()
# run_find_lr(learn, "stage2-3epochs-96_128-rescaled")

# %%
initial_lr = 1e-3
lr = 1e-5
lr_end = initial_lr / 5
n_epochs =  6

# %%
# with neptune.create_experiment(params = {
#                                         "initial_lr": initial_lr,
#                                         "lr": lr,
#                                         "lr_end": lr_end,
#                                         "n_epochs": n_epochs
#                                         }): 
#     learn.callbacks.append(NeptuneMonitor())
run_training(learn=learn, model_name="stage2-6epochs-96_128-rescaled", lr=lr, lr_end=lr_end, n_epochs=n_epochs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.962095</td>
#       <td>1.842613</td>
#       <td>0.500733</td>
#       <td>22:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.655957</td>
#       <td>1.862645</td>
#       <td>0.508733</td>
#       <td>22:58</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.495792</td>
#       <td>1.797578</td>
#       <td>0.555286</td>
#       <td>22:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.393088</td>
#       <td>1.777252</td>
#       <td>0.555309</td>
#       <td>22:26</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.339182</td>
#       <td>1.882536</td>
#       <td>0.550954</td>
#       <td>22:29</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.317027</td>
#       <td>1.888605</td>
#       <td>0.554254</td>
#       <td>22:23</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.8426131010055542.
# Better model found at epoch 2 with valid_loss value: 1.7975778579711914.
# Better model found at epoch 3 with valid_loss value: 1.7772517204284668.
# Loaded best saved model from /home/jupyter/training/wandb/run-20200311_214730-1ib0zu0a/bestmodel.pth

# %%
learn.recorder.plot_losses()

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
