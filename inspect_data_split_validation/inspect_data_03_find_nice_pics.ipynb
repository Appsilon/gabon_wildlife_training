# %% [markdown]
# in this noteboook we:
# * look for nice pictures for publicity

# %%
import pandas as pd
from pathlib import Path
import os

from fastai.vision import *

import random

from IPython.display import Image, display

# %%
DATA_PATH = Path("/data/Gabon_trainingData")

# %%
labels = pd.read_csv("/data/Labels/labels_clean.csv")

# %%
labels.head()
# Out:
#   species    n   uniqueName
# 0   Human  1.0  0000001.jpg
# 1   Blank  0.0  0000002.jpg
# 2   Human  1.0  0000003.jpg
# 3   Blank  0.0  0000004.jpg
# 4   Human  1.0  0000005.jpg

# %%
species = labels.species.unique().tolist()
len(species)
# Out:
# 29

# %%
def plot_animal(animal):
    labels_animal = labels[labels.species == animal]
    labels_animal = labels_animal.reset_index()

    rows = 8
    columns = 4
    _,axs = plt.subplots(rows,columns,figsize=(25,rows*5.5))
    for i,ax in enumerate(axs.flatten()):
        number = random.randint(0,len(labels_animal))
        idx = labels_animal.iloc[number,0]
        img_label = labels.uniqueName[idx]
        img = open_image(DATA_PATH / img_label)
        img.show(ax=axs[i//columns,i%columns], title=img_label)

# %%
i=28

# %%
animal = species[i]
print(i, " ", animal)
plot_animal(animal)
i += 1
# Out:
# 28   Cat_Golden
# Error in callback <function flush_figures at 0x7f44ffdac4d0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ...

# %%
img_ids = [
    # Elephant_African
    "1524554",
    "0749422",
    "1518962",
    # Leopard_African
    "1216809",
    "1225932",
    # Duiker_Red
    "1235067",
    # Guineafowl_Black
    "1248678",
#     Rail_Nkulengu
    "1383142",
#     mammal
    "1220286",
#     chimpanzee
    "1204380",
    "1209353",
#     Gorilla
    "1224315",
    "1216496",
#     Pangolin
    "1210352",
#     Mandrillus
    "1224353",
    "1234670",
    "1229003",
#     Civet_African_Palm  - nandinia palmowa
    "1405256",
#     Chevrotain_Water
    "1589931",
#     Cat_Golden
    "1228425",
    "1207816"
]

# %%
j=0

# %%
img = Image(filename='/data/Gabon_trainingData/'+img_ids[j]+".jpg")
j+=1
img

# %%
import shutil

# %%
for img_id in img_ids:
    img_file = img_id + ".jpg"
    shutil.copyfile(DATA_PATH / img_file, Path("/home/jupyter/nice_pics") / img_file)
